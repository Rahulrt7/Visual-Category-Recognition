# %%
import os
import itertools
from time import time

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

from skimage import io
from sklearn.neighbors import NearestNeighbors
from sklearn.svm import SVC
from skimage.transform import resize
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %matplotlib inline

# %%
# Divide the data into training data and validation data
# depending upon percentage of training data that must be used
def seperateData(allList, percentage, path, length ):
    
    trainLen = int (length* (percentage/100.0))
    trainList = [path + "/" + allList[i] for i in range(trainLen)]
    valList = [path + "/" + allList[i] for i in range(trainLen+1, length)]
    return trainList, valList

# %%
categories = os.listdir("101_ObjectCategories/")
# Object to store all the item details
objects = dict()
for name in categories:
    path = "./101_ObjectCategories/" + name
    temp = os.listdir(path)
    numberOfImages = len(temp)
    #print name 
    #print temp
    #print numberOfImages
    path = "./101_ObjectCategories/" + name
    trainList, valList = seperateData(temp, 85, path, numberOfImages)
    
    #objects[name] = dict(numberOfImages = numberOfImages)
    objects[name] = dict(
        numberOfImages = numberOfImages,
        trainingData = trainList,
        validationData= valList
    )

# %%
"""
for i in objects:
    print objects[i]
"""
# Out:
# '\nfor i in objects:\n    print objects[i]\n'

# %%
"""image_mat = io.imread(objects['sunflower']['trainingData'][0], as_grey=True)
io.imshow(image_mat)"""
# Out:
# "image_mat = io.imread(objects['sunflower']['trainingData'][0], as_grey=True)\nio.imshow(image_mat)"

# %%
def flattenImage(image =None):
    if image is not None:
        image2DMatrix = resize(io.imread(image, as_grey=True), (300, 167))
        imageVector = []
        for row in image2DMatrix:
            #print row
            for pixel in row:
                imageVector.append(pixel)
        
        # Testing (OK - TESTED)
        """
        image_mat_valid = image2DMatrix
        image_vector_valid = []
        for i in range(0, len(image_mat_valid)):
            for j in range(0, len(image_mat_valid[0])):
                image_vector_valid.append(image_mat_valid[i][j])
                
        print "TEST: ", image2DMatrix[-1][-1]
        print image_vector_valid == imageVector
        # OK (TESTED)
        """
        
        return imageVector
            
    else:
        raise IOError("Invalid Inputs")

# %%
# INPUT: Object with json format of validation and training data images
# OUTPUT: training image matrix:  which containst the images which are to used for training
#         label array: which contains the label corresponding to the given row of the training image matrix
def prepareTrainingData(imagesPerClass = 1, objects = None):
    trainingImageMatrix = []
    trainingLabel = []
    if objects is not None:
        for i in objects:
            if imagesPerClass < objects[i]['trainingData']:
                x = objects[i]['trainingData'][:imagesPerClass]
            else:
                x = objects[i]['trainingData']
            for j in x:
                trainingImageMatrix.append(flattenImage(j))
                trainingLabel.append(i)
        return trainingImageMatrix, trainingLabel 

    else:
        raise IOError("Give the valid input")

# %%
#flattenImage(image = objects['sunflower']['trainingData'][0])

# %%
print "Preparing training data"
trainingMatrix, trainingLabels = prepareTrainingData(imagesPerClass = 10 , objects = objects)
print "Traning data prepared\n Length of training matrix = ",
# Out:
# Preparing training data
# Traning data prepared
#  Length of training matrix =

# %%
print len(trainingMatrix)
# Out:
# 1010

# %% [markdown]
# ### Applying PCA for dimensionality Reduction

# %%
# Keeping track of time taken by PCA algorithm
t0 = time()
print "PCA Started"
pca = PCA(n_components=50, whiten=True).fit(trainingMatrix)
print "Time taken by PCA %0.3fs::" % (time() - t0)
pca.explained_variance_ratio_
# Out:
# PCA Started
# Time taken by PCA 21.218s::
# array([ 0.44027534,  0.05152309,  0.04304028,  0.02851926,  0.02450832,
#         0.02198139,  0.01556437,  0.01526241,  0.01141861,  0.0109184 ,
#         0.00909966,  0.0084253 ,  0.00804339,  0.00776662,  0.00720269,
#         0.0070676 ,  0.00526938,  0.00501909,  0.00481673,  0.00453654,
#         0.00438057,  0.00419996,  0.00396713,  0.00379915,  0.0036469 ,
#         0.00341137,  0.00315421,  0.00313075,  0.00284443,  0.00275808,
#         0.00260729,  0.00260027,  0.00252644,  0.00242987,  0.0023175 ,
#         0.00216594,  0.0021577 ,  0.00212244,  0.00207466,  0.00203396,
#         0.00194512,  0.00193419,  0.00185499,  0.00177074,  0.00174932,
#         0.00170831,  0.00165874,  0.00159767,  0.00157635,  0.00152751])

# %%
# projecting the input data on the eigenfaces orthonormal basis
print "Projecting the input data values"
t0 = time()
X_train_pca = pca.transform(trainingMatrix)

# The below line is currently not needed..Moreover, the code corresponding to
# validation matrix has been changed
# X_test_pca = pca.transform(validation_matrix)

print "Time taken for projection = %0.3fs" % (time() - t0)
print X_train_pca
# Out:
# Projecting the input data values
# Time taken for projection = 12.410s
# [[ 0.61526614 -0.81244153  1.73162781 ..., -2.41694565 -0.61488453
#   -2.09565736]
#  [ 0.30492132  0.73136907 -0.96240133 ...,  0.21734953  0.75392272
#   -0.26757773]
#  [ 0.39101205 -0.34043336  1.48806841 ...,  0.5413706  -0.11702148
#    0.23747234]
#  ...,
#  [ 0.14925871 -1.36738251  0.00912432 ..., -0.11943827 -0.09357356
#    0.13337292]
#  [ 0.92670604  0.03095425 -1.1386558  ..., -0.61086161 -1.84725394
#    3.17859932]
#  [-1.16644114 -1.32375174  1.07548534 ...,  0.14037713  1.02337287
#    0.64155657]]

# %% [markdown]
# ## Below code will run against each query to make prediction

# %%
"""
using kNN algorithm to find (k) nearest neighbours on complete dataset(training matrix), value of k(n_neighbours) 
is assigned to 100 for optimal behaviour
"""

def kNN(k, image_transform):
    neigh = NearestNeighbors(n_neighbors=k)
    neigh.fit(X_train_pca)
    
    distances, indices = neigh.kneighbors(image_transform)
    return indices[0]

# checking if the neighbours have similar labels. If yes then we can return this common label wihthout training SVM
def check_similarity(indices):
    flag = 0
    for i in range(0, len(indices)):
        for j in range(0, len(indices)):
            if trainingLabels[i] != trainingLabels[j]:
                flag = 1
                break
        if flag == 1:
            break
    # if labels are similar return or print the result, else train the SVM on neighbors matrix
    if flag == 0:
        return 0
    else:
        return 1


# Training SVM classifier only on k nearest neighbors
# GridSearchCV search over all the possible combinations of parameters of SVM classifier and choose the best one
def SVM(near_train, near_label, image_transform):
    t0 = time()
    # Here 'C' and 'gamma' are parameters provided as argument to SVM classifier
    param_grid = {'C': [1e3, 5e3, 1e4, 5e4, 1e5],
                  'gamma': [0.0001, 0.0005, 0.001, 0.005, 0.01, 0.1], }
    classifier = GridSearchCV(SVC(kernel="rbf", class_weight="balanced"), param_grid)

    classifier = classifier.fit(near_train, near_label)
    print "Time taken for training SVM classifier %0.3fs\n" % (time() - t0)

    # Display the optimal value of parameters found by grid search
    print "Best Estimator found by grid search ::"
    print classifier.best_estimator_
    
    # Predicting using trained classifier
    return classifier.predict(image_transform)

# %%
# Driver function for calling transforming image and calling kNN-SVM classifiers

def make_prediction(image_array =[], k = None, originalLabel = None):
    if image is not None and k is not None and originalLabel is not None:
        # Convert the vector into a numpy array and fit it using pca  
        flat_image_array = np.array(image_array, dtype= float).reshape(1,-1)
        image_transform = pca.transform(flat_image_array)

        indices = kNN(k, image_transform)
        flag = check_similarity(indices)
        if flag == 0:
            # predicted image
            prediction = trainingLabels[indices[0]]
            print "\n(Prediction made by kNN classifier only)"
        else:
            # constructing new train_matrix and label_matix of neighbours
            near_train = []
            near_label = []
            for index in indices:
                near_train.append(X_train_pca[index])
                near_label.append(trainingLabels[index])
            # calling SVM on limited number of training examples(neighbors)
            prediction = SVM(near_train, near_label, image_transform)
            prediction = prediction[0] # label returned as a list, extracting string label from list
            print "\n(Prediction made using both kNN and SVM)"

        # displaying output
        print "Predicted label of image:"
        print prediction
        print "\nOriginal label of image:"
        print originalLabel

        print "\n\n"
        print "Chosen image is displayed below:"
        io.imshow(io.imread(image, as_grey=True))
        return (prediction == originalLabel)
    else: 
        raise IOError("Some of the inputs are not valid")

# %%
label = "sunflower"
image = objects[label]['validationData'][1]
image_array = flattenImage(image = image)
start = time()
print make_prediction(image_array = image_array , k = 50, originalLabel =label)
print "Total Time taken =", time()- start
# Out:
# /home/a/miniconda2/envs/alt-env/lib/python2.7/site-packages/sklearn/model_selection/_split.py:579: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of groups for any class cannot be less than n_splits=3.
#   % (min_groups, self.n_splits)), Warning)
# Time taken for training SVM classifier 5.785s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# schooner
#
# Original label of image:
# sunflower
#
#
#
# Chosen image is displayed below:
# False
# Total Time taken = 6.02588391304

# %% [markdown]
# ### Prepare to find the mean accuracy of the classifier

# %%
def count_validation(objects):
    count =  0
    m = float("inf")
    for i in objects:
        temp = len(objects[i]['validationData'])
        m = min(m, temp)
        #print temp
        count += temp
    print m
    return count

# %%
print "Total number of validation data = ", count_validation(objects)
# Out:
# Total number of validation data =  4
# 1249

# %%
# INPUT: Object with json format of validation and training data images
# OUTPUT: validation image matrix:  which containst the images which are to used for validation
#         label array: which contains the label corresponding to the given row of the validation image matrix
def prepareValidationData(numberOfImages = 5, objects = None):
    validationImageMatrix = []
    labels = []
    start = time()
    if objects is not None:
        for i in objects:
            print "class = ", i
            for j in objects[i]['validationData'][:numberOfImages]:
                validationImageMatrix.append(flattenImage(j))
                labels.append(i)
        print "Total time taken to prepare validation matrix = ", time()-start
        return validationImageMatrix, labels 
        
    else:
        raise IOError("Give the valid input")

# %%
validationMatrix, validationLabels = prepareValidationData(numberOfImages = 5 , objects = objects)
# Out:
# class =  llama
# class =  lotus
# class =  laptop
# class =  brain
# class =  chandelier
# class =  chair
# class =  stop_sign
# class =  joshua_tree
# class =  sunflower
# class =  accordion
# class =  mandolin
# class =  scorpion
# class =  ewer
# class =  schooner
# class =  dragonfly
# class =  stegosaurus
# class =  menorah
# class =  crocodile
# class =  cannon
# class =  watch
# class =  sea_horse
# class =  snoopy
# class =  tick
# class =  Motorbikes
# class =  flamingo
# class =  stapler
# class =  electric_guitar
# class =  emu
# class =  saxophone
# class =  brontosaurus
# class =  bonsai
# class =  lobster
# class =  umbrella
# class =  gramophone
# class =  panda
# class =  car_side
# class =  pigeon
# class =  revolver
# class =  rhino
# class =  buddha
# class =  windsor_chair
# class =  Leopards
# class =  flamingo_head
# class =  soccer_ball
# class =  bass
# class =  trilobite
# class =  kangaroo
# class =  gerenuk
# class =  pagoda
# class =  ibis
# class =  Faces
# class =  dalmatian
# class =  cup
# class =  octopus
# class =  headphone
# class =  pyramid
# class =  scissors
# class =  yin_yang
# class =  wild_cat
# class =  camera
# class =  crab
# class =  helicopter
# class =  cougar_body
# class =  starfish
# class =  grand_piano
# class =  ceiling_fan
# class =  mayfly
# class =  crocodile_head
# class =  metronome
# class =  minaret
# class =  strawberry
# class =  cougar_face
# class =  ferry
# class =  anchor
# class =  inline_skate
# class =  nautilus
# class =  ketch
# class =  dolphin
# class =  rooster
# class =  ant
# class =  euphonium
# class =  garfield
# class =  water_lilly
# class =  beaver
# class =  binocular
# class =  dollar_bill
# class =  lamp
# class =  Faces_easy
# class =  elephant
# class =  hawksbill
# class =  pizza
# class =  butterfly
# class =  airplanes
# class =  cellphone
# class =  wheelchair
# class =  platypus
# class =  wrench
# class =  okapi
# class =  barrel
# class =  crayfish
# class =  hedgehog
# Total time taken to prepare validation matrix =  27.5807359219

# %%
print len(validationLabels)
print len(validationMatrix)
# Out:
# 502
# 502

# %%
# Custom Built accuracy function to find the accuracy of the 
# classifer for the given set of validation data
def customAccuracy(validationMatrix = None , validationLabels = None):
    if validationMatrix is not None and validationLabels is not None:
        correct = 0 
        incorrect = 0
        n = len(validationLabels)
        start = time()
        for i in range(n):
            this_start = time()
            verdict = make_prediction(image_array = validationMatrix[i], k = 500, originalLabel = validationLabels[i])
            if verdict :
                correct += 1
            this_end = time()-this_start
            print "i = %s, verdict = %s, time = %s" %(str(i), str(verdict), str(this_end))
        end = time() - start
        print "total time taken =", end
        print "Total number of correct predictions are", correct
        print "----Finding accuracy ----"
        accuracy =  float(correct)/ float(n)
        return accuracy
    else: 
        raise IOError("Some of the inputs are not valid")

# %%
customAccuracy(validationMatrix = validationMatrix, validationLabels = validationLabels)
# Out:
# Time taken for training SVM classifier 38.310s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.005, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# windsor_chair
#
# Original label of image:
# llama
#
#
#
# Chosen image is displayed below:
# i = 0, verdict = False, time = 38.5604269505
# Time taken for training SVM classifier 36.613s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# lamp
#
# Original label of image:
# llama
#
#
#
# Chosen image is displayed below:
# i = 1, verdict = False, time = 36.6858439445
# Time taken for training SVM classifier 37.377s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.001, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# saxophone
#
# Original label of image:
# llama
#
#
#
# Chosen image is displayed below:
# i = 2, verdict = False, time = 37.4464309216
# Time taken for training SVM classifier 36.735s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# metronome
#
# Original label of image:
# llama
#
#
#
# Chosen image is displayed below:
# i = 3, verdict = False, time = 36.8042120934
# Time taken for training SVM classifier 37.330s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# airplanes
#
# Original label of image:
# llama
#
#
#
# Chosen image is displayed below:
# i = 4, verdict = False, time = 37.3993690014
# Time taken for training SVM classifier 36.289s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# garfield
#
# Original label of image:
# lotus
#
#
#
# Chosen image is displayed below:
# i = 5, verdict = False, time = 36.3576340675
# Time taken for training SVM classifier 36.077s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# ewer
#
# Original label of image:
# lotus
#
#
#
# Chosen image is displayed below:
# i = 6, verdict = False, time = 36.1465809345
# Time taken for training SVM classifier 38.806s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# flamingo
#
# Original label of image:
# lotus
#
#
#
# Chosen image is displayed below:
# i = 7, verdict = False, time = 38.8725171089
# Time taken for training SVM classifier 35.652s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.001, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# joshua_tree
#
# Original label of image:
# lotus
#
#
#
# Chosen image is displayed below:
# i = 8, verdict = False, time = 35.718542099
# Time taken for training SVM classifier 36.602s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# hawksbill
#
# Original label of image:
# lotus
#
#
#
# Chosen image is displayed below:
# i = 9, verdict = False, time = 36.6687748432
# Time taken for training SVM classifier 36.698s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.0005, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# ant
#
# Original label of image:
# laptop
#
#
#
# Chosen image is displayed below:
# i = 10, verdict = False, time = 36.7647299767
# Time taken for training SVM classifier 36.760s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# car_side
#
# Original label of image:
# laptop
#
#
#
# Chosen image is displayed below:
# i = 11, verdict = False, time = 36.8260598183
# Time taken for training SVM classifier 38.995s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.0001, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# laptop
#
# Original label of image:
# laptop
#
#
#
# Chosen image is displayed below:
# i = 12, verdict = True, time = 39.0613050461
# Time taken for training SVM classifier 36.897s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.0001, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# llama
#
# Original label of image:
# laptop
#
#
#
# Chosen image is displayed below:
# i = 13, verdict = False, time = 36.9634218216
# Time taken for training SVM classifier 36.607s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.005, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# nautilus
#
# Original label of image:
# laptop
#
#
#
# Chosen image is displayed below:
# i = 14, verdict = False, time = 36.6794140339
# Time taken for training SVM classifier 38.021s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.005, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# mayfly
#
# Original label of image:
# brain
#
#
#
# Chosen image is displayed below:
# i = 15, verdict = False, time = 38.0950028896
# Time taken for training SVM classifier 36.836s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# cougar_face
#
# Original label of image:
# brain
#
#
#
# Chosen image is displayed below:
# i = 16, verdict = False, time = 36.9037630558
# Time taken for training SVM classifier 36.027s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.005, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# saxophone
#
# Original label of image:
# brain
#
#
#
# Chosen image is displayed below:
# i = 17, verdict = False, time = 36.0964210033
# Time taken for training SVM classifier 36.649s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.0001, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# mayfly
#
# Original label of image:
# brain
#
#
#
# Chosen image is displayed below:
# i = 18, verdict = False, time = 36.7173030376
# Time taken for training SVM classifier 36.666s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# crocodile
#
# Original label of image:
# brain
#
#
#
# Chosen image is displayed below:
# i = 19, verdict = False, time = 36.7334170341
# Time taken for training SVM classifier 36.874s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.0001, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# flamingo_head
#
# Original label of image:
# chandelier
#
#
#
# Chosen image is displayed below:
# i = 20, verdict = False, time = 36.9430959225
# Time taken for training SVM classifier 36.311s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# menorah
#
# Original label of image:
# chandelier
#
#
#
# Chosen image is displayed below:
# i = 21, verdict = False, time = 36.3782141209
# Time taken for training SVM classifier 36.637s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.0001, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# electric_guitar
#
# Original label of image:
# chandelier
#
#
#
# Chosen image is displayed below:
# i = 22, verdict = False, time = 36.7043378353
# Time taken for training SVM classifier 37.269s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# platypus
#
# Original label of image:
# chandelier
#
#
#
# Chosen image is displayed below:
# i = 23, verdict = False, time = 37.338064909
# Time taken for training SVM classifier 36.853s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# kangaroo
#
# Original label of image:
# chandelier
#
#
#
# Chosen image is displayed below:
# i = 24, verdict = False, time = 36.9196810722
# Time taken for training SVM classifier 36.511s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.0001, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# Faces
#
# Original label of image:
# chair
#
#
#
# Chosen image is displayed below:
# i = 25, verdict = False, time = 36.5784668922
# Time taken for training SVM classifier 36.812s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# sea_horse
#
# Original label of image:
# chair
#
#
#
# Chosen image is displayed below:
# i = 26, verdict = False, time = 36.8808810711
# Time taken for training SVM classifier 37.291s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.005, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# Faces
#
# Original label of image:
# chair
#
#
#
# Chosen image is displayed below:
# i = 27, verdict = False, time = 37.3591499329
# Time taken for training SVM classifier 35.757s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.0001, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# ant
#
# Original label of image:
# chair
#
#
#
# Chosen image is displayed below:
# i = 28, verdict = False, time = 35.8250088692
# Time taken for training SVM classifier 36.391s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.005, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# barrel
#
# Original label of image:
# chair
#
#
#
# Chosen image is displayed below:
# i = 29, verdict = False, time = 36.4593689442
# Time taken for training SVM classifier 36.255s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.005, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# stop_sign
#
# Original label of image:
# stop_sign
#
#
#
# Chosen image is displayed below:
# i = 30, verdict = True, time = 36.3237791061
# Time taken for training SVM classifier 36.565s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# hedgehog
#
# Original label of image:
# stop_sign
#
#
#
# Chosen image is displayed below:
# i = 31, verdict = False, time = 36.6340060234
# Time taken for training SVM classifier 39.038s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# kangaroo
#
# Original label of image:
# stop_sign
#
#
#
# Chosen image is displayed below:
# i = 32, verdict = False, time = 39.1061849594
# Time taken for training SVM classifier 36.767s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# water_lilly
#
# Original label of image:
# stop_sign
#
#
#
# Chosen image is displayed below:
# i = 33, verdict = False, time = 36.8342189789
# Time taken for training SVM classifier 36.438s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.005, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# chandelier
#
# Original label of image:
# stop_sign
#
#
#
# Chosen image is displayed below:
# i = 34, verdict = False, time = 36.5058760643
# Time taken for training SVM classifier 36.793s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# brontosaurus
#
# Original label of image:
# joshua_tree
#
#
#
# Chosen image is displayed below:
# i = 35, verdict = False, time = 36.8602950573
# Time taken for training SVM classifier 36.544s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.0001, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# strawberry
#
# Original label of image:
# joshua_tree
#
#
#
# Chosen image is displayed below:
# i = 36, verdict = False, time = 36.6118628979
# Time taken for training SVM classifier 36.640s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# dolphin
#
# Original label of image:
# joshua_tree
#
#
#
# Chosen image is displayed below:
# i = 37, verdict = False, time = 36.7078289986
# Time taken for training SVM classifier 36.807s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# ferry
#
# Original label of image:
# joshua_tree
#
#
#
# Chosen image is displayed below:
# i = 38, verdict = False, time = 36.8745880127
# Time taken for training SVM classifier 36.853s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.005, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# brontosaurus
#
# Original label of image:
# joshua_tree
#
#
#
# Chosen image is displayed below:
# i = 39, verdict = False, time = 36.9209361076
# Time taken for training SVM classifier 36.872s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.005, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# elephant
#
# Original label of image:
# sunflower
#
#
#
# Chosen image is displayed below:
# i = 40, verdict = False, time = 36.9388217926
# Time taken for training SVM classifier 36.519s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.005, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# ferry
#
# Original label of image:
# sunflower
#
#
#
# Chosen image is displayed below:
# i = 41, verdict = False, time = 36.5868549347
# Time taken for training SVM classifier 36.151s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.005, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# sunflower
#
# Original label of image:
# sunflower
#
#
#
# Chosen image is displayed below:
# i = 42, verdict = True, time = 36.2181110382
# Time taken for training SVM classifier 36.850s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# bonsai
#
# Original label of image:
# sunflower
#
#
#
# Chosen image is displayed below:
# i = 43, verdict = False, time = 36.9183869362
# Time taken for training SVM classifier 36.887s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.005, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# brain
#
# Original label of image:
# sunflower
#
#
#
# Chosen image is displayed below:
# i = 44, verdict = False, time = 36.9551100731
# Time taken for training SVM classifier 36.399s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# chandelier
#
# Original label of image:
# accordion
#
#
#
# Chosen image is displayed below:
# i = 45, verdict = False, time = 36.4677171707
# Time taken for training SVM classifier 36.484s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# wheelchair
#
# Original label of image:
# accordion
#
#
#
# Chosen image is displayed below:
# i = 46, verdict = False, time = 36.5525891781
# Time taken for training SVM classifier 36.320s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.005, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# mandolin
#
# Original label of image:
# accordion
#
#
#
# Chosen image is displayed below:
# i = 47, verdict = False, time = 36.3880860806
# Time taken for training SVM classifier 35.679s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.005, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# metronome
#
# Original label of image:
# accordion
#
#
#
# Chosen image is displayed below:
# i = 48, verdict = False, time = 35.7473170757
# Time taken for training SVM classifier 36.398s
#
# Best Estimator found by grid search ::
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# (Prediction made using both kNN and SVM)
# Predicted label of image:
# electric_guitar
#
# Original label of image:
# accordion
#
#
#
# Chosen image is displayed below:
# i = 49, verdict = False, time = 36.471296072
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-4429087a7a04> in <module>()
# ----> 1 customAccuracy(validationMatrix = validationMatrix, validationLabels = validationLabels)
#
# <ipython-input-24-9cf62461d599> in customAccuracy(validationMatrix, validationLabels)
#       9         for i in range(n):
#      10             this_start = time()
# ---> 11             verdict = make_prediction(image_array = validationMatrix[i], k = 500, originalLabel = validationLabels[i])
#      12             if verdict :
#      13                 correct += 1
#
# <ipython-input-14-03d6cef5c015> in make_prediction(image_array, k, originalLabel)
#      21                 near_label.append(trainingLabels[index])
#      22             # calling SVM on limited number of training examples(neighbors)
# ---> 23             prediction = SVM(near_train, near_label, image_transform)
#      24             prediction = prediction[0] # label returned as a list, extracting string label from list
#      25             print "\n(Prediction made using both kNN and SVM)"
#
# <ipython-input-13-7c58f98e865b> in SVM(near_train, near_label, image_transform)
#      37     classifier = GridSearchCV(SVC(kernel="rbf", class_weight="balanced"), param_grid)
#      38
# ---> 39     classifier = classifier.fit(near_train, near_label)
#      40     print "Time taken for training SVM classifier %0.3fs\n" % (time() - t0)
#      41
#
# /home/a/miniconda2/envs/alt-env/lib/python2.7/site-packages/sklearn/model_selection/_search.pyc in fit(self, X, y, groups)
#     938             train/test set.
#     939         """
# --> 940         return self._fit(X, y, groups, ParameterGrid(self.param_grid))
#     941
#     942
#
# /home/a/miniconda2/envs/alt-env/lib/python2.7/site-packages/sklearn/model_selection/_search.pyc in _fit(self, X, y, groups, parameter_iterable)
#     560                                   return_times=True, return_parameters=True,
#     561                                   error_score=self.error_score)
# --> 562           for parameters in parameter_iterable
#     563           for train, test in cv.split(X, y, groups))
#     564
#
# /home/a/miniconda2/envs/alt-env/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     756             # was dispatched. In particular this covers the edge
#     757             # case of Parallel used with an exhausted iterator.
# --> 758             while self.dispatch_one_batch(iterator):
#     759                 self._iterating = True
#     760             else:
#
# /home/a/miniconda2/envs/alt-env/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch_one_batch(self, iterator)
#     606                 return False
#     607             else:
# --> 608                 self._dispatch(tasks)
#     609                 return True
#     610
#
# /home/a/miniconda2/envs/alt-env/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in _dispatch(self, batch)
#     569         dispatch_timestamp = time.time()
#     570         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 571         job = self._backend.apply_async(batch, callback=cb)
#     572         self._jobs.append(job)
#     573
#
# /home/a/miniconda2/envs/alt-env/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in apply_async(self, func, callback)
#     107     def apply_async(self, func, callback=None):
#     108         """Schedule a func to be run"""
# --> 109         result = ImmediateResult(func)
#     110         if callback:
#     111             callback(result)
#
# /home/a/miniconda2/envs/alt-env/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in __init__(self, batch)
#     320         # Don't delay the application, to avoid keeping the input
#     321         # arguments in memory
# --> 322         self.results = batch()
#     323
#     324     def get(self):
#
# /home/a/miniconda2/envs/alt-env/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /home/a/miniconda2/envs/alt-env/lib/python2.7/site-packages/sklearn/model_selection/_validation.pyc in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, error_score)
#     236             estimator.fit(X_train, **fit_params)
#     237         else:
# --> 238             estimator.fit(X_train, y_train, **fit_params)
#     239
#     240     except Exception as e:
#
# /home/a/miniconda2/envs/alt-env/lib/python2.7/site-packages/sklearn/svm/base.pyc in fit(self, X, y, sample_weight)
#     187
#     188         seed = rnd.randint(np.iinfo('i').max)
# --> 189         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     190         # see comment on the other call to np.iinfo in this file
#     191
#
# /home/a/miniconda2/envs/alt-env/lib/python2.7/site-packages/sklearn/svm/base.pyc in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     254                 cache_size=self.cache_size, coef0=self.coef0,
#     255                 gamma=self._gamma, epsilon=self.epsilon,
# --> 256                 max_iter=self.max_iter, random_seed=random_seed)
#     257
#     258         self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %% [markdown]
# ## Accuracy of the classifier

# %%
start = time()
print "PCA on validation matrix started"
X_test_pca = pca.transform(validationMatrix)
print "PCA Completed. Time taken = ", time()-start
accuracy = classifier.score(X_test_pca, validationLabels)

# %%
print accuracy

# %%
import random
print random.sample(range(1,20), 4)
